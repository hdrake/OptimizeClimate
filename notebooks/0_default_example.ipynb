# %%
using PyPlot
using JuMP, Ipopt

# %%
include("../src/model.jl");
include("../src/diagnostics.jl");
include("../src/optimization.jl");
include("../src/plotting.jl");
include("../src/defaults.jl");

# %% [markdown]
# # Optimizating the Global Climate Action Policy Portfolio

# %%
model = ClimateModel();
@time optimize_controls!(model);
plot_state(model);
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
#  44.208946
# Figure(PyObject <Figure size 1400x800 with 6 Axes>)
#  seconds (114.46 M allocations: 6.482 GiB, 6.00% gc time)

# %%
model = ClimateModel();
@time optimize_controls!(model, obj_option = "net_benefit");
plot_state(model);
# Out:
# Figure(PyObject <Figure size 1400x800 with 6 Axes>)
#   0.239717 seconds (216.46 k allocations: 10.424 MiB)
