# %%
using PyPlot
using JuMP, Ipopt

# %%
include("../src/model.jl");
include("../src/diagnostics.jl");
include("../src/optimization.jl");
include("../src/plotting.jl");

# %% [markdown]
# ## Model setup
#
# #### Physical parameters

# %%
# Model domain
dt = 1.
t = Array(2020:dt:2200);

# "Best-guess equilibrium climate sensitivity"
ECS = 3.0;

# %% [markdown]
# #### Economic parameters
#
# Assume damages of 2% of global world product (GWP) for 3$^{\circ}$C of warming (similar to DICE damage function).

# %%
GWP = 100. # global world product (trillion $ / year)

β = 0.02*GWP/(3.0)^2 # damages (trillion USD / year / celsius^2)
utility_discount_rate = 0.025 # ρ (relative low value from Stern review)

# Control technology cost scales (for full deployment, α=1.)
reduce_cost = 0.01*GWP;
remove_cost = 0.02*GWP;
geoeng_cost = 0.05*GWP;
adapt_cost = 0.03*GWP;

# %%
baseline_emissions_scenario = baseline_emissions(t, 5., 2060., 40.)

economics = Economics(
    β, utility_discount_rate,
    reduce_cost, remove_cost, geoeng_cost, adapt_cost,
    0., 0., 0., 0., # Assumed initial condition of no deployments in 2020
    baseline_emissions_scenario
);

# %% [markdown]
# ### Initialize model

# %%
ensemble = Dict{String, ClimateModel}();

name = "Example configuration";
present_year = 2020.

# Arbitrary initial guess of climate control policies,
# to be optimized later!
controls = init_zero_controls(t);

# Create instance of idealized integrated assessment climate model
model = ClimateModel(name, ECS, t, dt, controls, economics, present_year);

# Plot initial state (baseline scenario; zero controls)
plot_state(model)

print(string(
        "Social cost of carbon: \$",
        SCC(model),"."))
# Out:
# Figure(PyObject <Figure size 1000x1200 with 6 Axes>)
# Social cost of carbon: $24.99.

# %% [markdown]
# # Model optimization
#
# ## Constraint on total discounted control budget

# %%
maxslope = 1. /30.
optimize_controls!(model, maxslope = maxslope, obj_option = "budget", budget=20.);
plot_state(model)
subplot(3,2,3)
plot([2020., 2020. + 1. /maxslope], [0.,1.], "k--", alpha=0.25)
# Out:
# Figure(PyObject <Figure size 1000x1200 with 6 Axes>)
# This is Ipopt version 3.12.10, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2776
# Number of nonzeros in inequality constraint Jacobian.:      720
# Number of nonzeros in Lagrangian Hessian.............:     2341
#
# Total number of variables............................:     1621
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1440
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      901
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0582464e+01 5.00e+00 8.30e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.8681409e+01 3.04e+00 8.49e-01  -1.0 2.25e+02    -  5.43e-01 3.91e-01f  1
#    2  1.6148216e+01 2.20e+00 3.43e+00  -1.0 1.03e+02    -  4.54e-01 2.76e-01f  1
#    3  1.3175054e+01 2.36e+00 4.36e-01  -1.0 7.89e+01    -  1.00e+00 1.00e+00f  1
#    4  1.2370478e+01 5.34e+00 8.99e-01  -1.0 9.74e+01    -  1.00e+00 3.54e-01f  1
#    5  1.5392083e+01 8.05e-01 2.97e-01  -1.0 2.33e+01    -  1.00e+00 1.00e+00h  1
#    6  1.4886283e+01 5.55e-02 2.05e-02  -1.7 8.53e+00    -  1.00e+00 1.00e+00h  1
#    7  1.2715075e+01 7.34e-01 1.70e-01  -2.5 3.61e+01    -  8.98e-01 1.00e+00f  1
#    8  1.1566463e+01 8.26e-01 2.97e-03  -2.5 3.15e+01    -  1.00e+00 1.00e+00h  1
#    9  1.1891500e+01 1.66e-02 5.37e-04  -2.5 9.26e+00    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1475128e+01 2.10e-01 2.17e-02  -3.8 1.25e+01    -  9.36e-01 1.00e+00f  1
#   11  1.1484478e+01 4.66e-02 3.58e-04  -3.8 7.63e+00    -  1.00e+00 1.00e+00h  1
#   12  1.1494120e+01 3.66e-03 3.24e-05  -3.8 1.60e+00    -  1.00e+00 1.00e+00h  1
#   13  1.1494639e+01 6.22e-15 2.94e-07  -3.8 1.45e-01    -  1.00e+00 1.00e+00h  1
#   14  1.1473651e+01 9.00e-03 3.83e-03  -5.7 2.54e+00    -  8.95e-01 1.00e+00f  1
#   15  1.1475393e+01 1.46e-03 8.63e-06  -5.7 6.06e-01    -  1.00e+00 1.00e+00h  1
#   16  1.1475512e+01 2.89e-04 9.98e-07  -5.7 2.19e-01    -  1.00e+00 1.00e+00h  1
#   17  1.1475554e+01 2.68e-05 7.21e-08  -5.7 4.39e-02    -  1.00e+00 1.00e+00h  1
#   18  1.1475556e+01 7.11e-15 1.28e-09  -5.7 4.24e-03    -  1.00e+00 1.00e+00h  1
#   19  1.1475380e+01 5.53e-05 4.27e-05  -8.6 7.84e-02    -  9.78e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.1475387e+01 1.06e-05 1.53e-08  -8.6 1.35e-02    -  1.00e+00 1.00e+00h  1
#   21  1.1475387e+01 2.62e-06 1.90e-09  -8.6 3.57e-03    -  1.00e+00 1.00e+00h  1
#   22  1.1475387e+01 5.96e-07 2.53e-10  -8.6 7.10e-04    -  1.00e+00 1.00e+00h  1
#   23  1.1475387e+01 1.04e-07 1.06e-11  -8.6 3.02e-04    -  1.00e+00 1.00e+00h  1
#   24  1.1475387e+01 4.27e-09 5.08e-14  -8.6 8.60e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 24
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1475386828532564e+01    1.1475386828532564e+01
# Dual infeasibility......:   5.0792739151748814e-14    5.0792739151748814e-14
# Constraint violation....:   4.2743488140695261e-09    4.2743488140695261e-09
# Complementarity.........:   2.6028302268913740e-09    2.6028302268913740e-09
# Overall NLP error.......:   4.2743488140695261e-09    4.2743488140695261e-09
#
#
# Number of objective function evaluations             = 25
# Number of objective gradient evaluations             = 25
# Number of equality constraint evaluations            = 25
# Number of inequality constraint evaluations          = 25
# Number of equality constraint Jacobian evaluations   = 25
# Number of inequality constraint Jacobian evaluations = 25
# Number of Lagrangian Hessian evaluations             = 24
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.287
# Total CPU secs in NLP function evaluations           =      0.431
#
# EXIT: Optimal Solution Found.
#   0.740504 seconds (1.59 M allocations: 74.694 MiB, 24.63% gc time)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x14d58d860>

# %%
maxslope = 1. /50.
optimize_controls!(model, maxslope = maxslope, obj_option = "budget", budget=5.);
plot_state(model)
subplot(3,2,3)
plot([2020., 2020. + 1. /maxslope], [0.,1.], "k--", alpha=0.25)
# Out:
# Figure(PyObject <Figure size 1000x1200 with 6 Axes>)
# This is Ipopt version 3.12.10, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2776
# Number of nonzeros in inequality constraint Jacobian.:      720
# Number of nonzeros in Lagrangian Hessian.............:     2341
#
# Total number of variables............................:     1621
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     1440
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      901
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        1
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0582464e+01 5.00e+00 8.30e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.6075469e+01 3.67e+00 2.08e+00  -1.0 2.26e+02    -  5.47e-01 2.67e-01f  1
#    2  1.5265277e+01 2.83e+00 6.04e+00  -1.0 6.82e+01    -  3.82e-01 2.28e-01f  1
#    3  1.6939622e+01 1.73e+00 1.11e+01  -1.0 8.53e+01    -  1.00e+00 4.50e-01f  1
#    4  2.4838050e+01 1.41e+00 2.64e+00  -1.0 1.06e+02    -  1.00e+00 6.08e-01f  1
#    5  3.0785544e+01 1.31e-01 2.45e-01  -1.0 6.26e+01    -  1.00e+00 1.00e+00h  1
#    6  3.0376066e+01 4.22e-03 8.62e-02  -1.7 4.60e+00    -  1.00e+00 1.00e+00h  1
#    7  2.8531924e+01 1.59e-01 1.81e-01  -2.5 1.64e+01    -  9.29e-01 1.00e+00f  1
#    8  2.7825996e+01 1.19e-01 2.38e-03  -2.5 1.22e+01    -  1.00e+00 1.00e+00f  1
#    9  2.8002416e+01 1.03e-03 1.16e-04  -2.5 4.67e+00    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.7740755e+01 3.09e-02 2.09e-02  -3.8 8.17e+00    -  9.56e-01 1.00e+00f  1
#   11  2.7742452e+01 6.57e-03 7.48e-05  -3.8 5.06e+00    -  1.00e+00 1.00e+00h  1
#   12  2.7746926e+01 4.48e-04 5.55e-06  -3.8 1.33e+00    -  1.00e+00 1.00e+00h  1
#   13  2.7734678e+01 1.40e-03 4.42e-03  -5.7 2.11e+00    -  9.00e-01 1.00e+00h  1
#   14  2.7735170e+01 2.51e-04 1.21e-06  -5.7 6.22e-01    -  1.00e+00 1.00e+00h  1
#   15  2.7735099e+01 5.94e-05 2.00e-08  -5.7 1.65e-01    -  1.00e+00 1.00e+00h  1
#   16  2.7735103e+01 7.20e-06 1.24e-10  -5.7 3.04e-02    -  1.00e+00 1.00e+00h  1
#   17  2.7734964e+01 1.38e-05 1.63e-05  -8.6 7.33e-02    -  9.79e-01 1.00e+00h  1
#   18  2.7734965e+01 3.29e-06 2.84e-11  -8.6 8.10e-03    -  1.00e+00 1.00e+00h  1
#   19  2.7734965e+01 8.35e-07 3.31e-12  -8.6 1.06e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.7734965e+01 1.93e-07 2.49e-14  -8.6 4.05e-04    -  1.00e+00 1.00e+00h  1
#   21  2.7734965e+01 3.56e-08 2.49e-14  -8.6 1.76e-04    -  1.00e+00 1.00e+00h  1
#   22  2.7734965e+01 2.19e-09 2.49e-14  -8.6 5.37e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 22
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7734964866910229e+01    2.7734964866910229e+01
# Dual infeasibility......:   2.4868995751603507e-14    2.4868995751603507e-14
# Constraint violation....:   2.1933583230315887e-09    2.1933583230315887e-09
# Complementarity.........:   2.6440490993361837e-09    2.6440490993361837e-09
# Overall NLP error.......:   2.6440490993361837e-09    2.6440490993361837e-09
#
#
# Number of objective function evaluations             = 23
# Number of objective gradient evaluations             = 23
# Number of equality constraint evaluations            = 23
# Number of inequality constraint evaluations          = 23
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 23
# Number of Lagrangian Hessian evaluations             = 22
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.095
# Total CPU secs in NLP function evaluations           =      0.028
#
# EXIT: Optimal Solution Found.
#   0.137548 seconds (378.05 k allocations: 10.780 MiB)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x14bf5eb38>

# %% [markdown]
# ## Annual expenditures constraint

# %%
maxslope = 1. /20.
optimize_controls!(model, maxslope = maxslope, obj_option = "expenditure", expenditure=0.5);
plot_state(model)
subplot(3,2,3)
plot([2020., 2020. + 1. /maxslope], [0.,1.], "k--", alpha=0.25)
# Out:
# Figure(PyObject <Figure size 1000x1200 with 6 Axes>)
# This is Ipopt version 3.12.10, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2776
# Number of nonzeros in inequality constraint Jacobian.:      720
# Number of nonzeros in Lagrangian Hessian.............:     2341
#
# Total number of variables............................:     1621
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     